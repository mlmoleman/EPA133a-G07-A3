# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_scenario0 = pd.read_csv('experiment/scenario0.csv')
df_scenario1 = pd.read_csv('experiment/scenario1.csv')
df_scenario2 = pd.read_csv('experiment/scenario2.csv')
df_scenario3 = pd.read_csv('experiment/scenario3.csv')
df_scenario4 = pd.read_csv('experiment/scenario4.csv')
dfs = [df_scenario0, df_scenario1, df_scenario2, df_scenario3, df_scenario4]

# %%
def adding_scenario_column(df, s):
    # Add a column with the number of the scenario
    df['scenario'] = s
    return df

# %%
def create_subset(df):
    # Create a subset of the dataframe with the desired columns
    df_subset = df[['scenario', 'iteration', 'Step', 
                    'avg_delay', 'avg_waiting','avg_driving_time', 'avg_speed',
                    'tot_collapsed', 'A_collapsed', 'B_collapsed', 'C_collapsed', 'D_collapsed']]
    return df_subset

# %%
def concat_dfs(dfs):
    # Create an empty list to store the cleaned dataframes in
    df_list = []
    # Loop over the dataframes
    for s, df in enumerate(dfs):
        # Add a column with the scenario number
        df = adding_scenario_column(df, s)
        # Create a subset of the dataframe
        df_subset = create_subset(df)
        # Append the cleaned dataframe to the list
        df_list.append(df_subset)
    # Concat the dataframes in the list
    full_df = pd.concat(df_list, ignore_index=True)
    return full_df

# %%
# Call the concat_function and assign the dataframe to full_df
full_df = concat_dfs(dfs)

# %%
full_df
# Out:
#         scenario  iteration  Step  avg_delay  avg_waiting  avg_driving_time  \
# 0              0          0     0   0.000000     0.000000          0.000000
# 1              0          0     1   0.000000     0.000000          0.000000
# 2              0          0     2   0.000000     0.000000          0.000000
# 3              0          0     3   0.000000     0.000000          0.000000
# 4              0          0     4   0.000000     0.000000          0.000000
# ...          ...        ...   ...        ...          ...               ...
# 360045         4          9  7196  25.590198    21.554374       2589.400883
# 360046         4          9  7197  25.726231    21.558471       2589.353025
# 360047         4          9  7198  25.587081    21.590901       2589.682762
# 360048         4          9  7199  25.807225    21.607084       2589.682762
# 360049         4          9  7200  25.571278    21.611517       2589.956398
#
#         avg_speed  tot_collapsed  A_collapsed  B_collapsed  C_collapsed  \
# 0        0.000000              0            0            0            0
# 1        0.000000              0            0            0            0
# 2        0.000000              0            0            0            0
# 3        0.000000              0            0            0            0
# 4        0.000000              0            0            0            0
# ...           ...            ...          ...          ...          ...
# 360045   2.408367           1668         1086          289          255
# 360046   2.408348           1668         1086          289          255
# 360047   2.408118           1668         1086          289          255
# 360048   2.408118           1668         1086          289          255
# 360049   2.408188           1668         1086          289          255
#
#         D_collapsed
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 360045           38
# 360046           38
# 360047           38
# 360048           38
# 360049           38
#
# [360050 rows x 12 columns]

# %%
# Filter on the rows with only the last time-step, as that is the step we are interested in for this KPI
df_laststep = full_df[full_df['Step']==7200]

# %%
# Create a barplot of the average driving time
plt.figure(figsize=(9, 6))
sns.barplot(x=df_laststep['scenario'], y=df_laststep['avg_driving_time'])
plt.title('Average driving time per truck')
plt.xlabel('Scenario')
plt.ylabel('Driving time (minutes)')
plt.savefig('img/barplot_avg_driving_time.png')
plt.show()

# %%
# Create a barplot of the average waiting time
plt.figure(figsize=(9, 6))
sns.barplot(x=df_laststep['scenario'], y=df_laststep['avg_delay'])
plt.title('Average delay time per truck')
plt.xlabel('Scenario')
plt.ylabel('Delay time (minutes)')
plt.savefig('img/barplot_avg_delay_time.png')
plt.show()

# %%
# Create a lineplot of the average speed
plt.figure(figsize=(9, 6))
sns.lineplot(data=full_df, x='Step', y='avg_speed', hue='scenario')
plt.title('Average speed per truck')
plt.xlabel('Step (minutes)')
plt.ylabel('Speed (km/h)')
plt.savefig('img/lineplot_avg_speed.png')
plt.show()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 15))
fig.suptitle('Total number of collapsed bridges')

sns.lineplot(data=full_df, x='Step', y='A_collapsed', hue='scenario', ax=ax1)
ax1.set_title('Collapsed bridges of condition A')
ax1.set_xlabel('Step (minutes)')
ax1.set_ylabel('Number of bridges')

sns.lineplot(data=full_df, x='Step', y='B_collapsed', hue='scenario', ax=ax2)
ax2.set_title('Collapsed bridges of condition B')
ax2.set_xlabel('Step (minutes)')
ax2.set_ylabel('Number of bridges')

sns.lineplot(data=full_df, x='Step', y='C_collapsed', hue='scenario', ax=ax3)
ax3.set_title('Collapsed bridges of condition C')
ax3.set_xlabel('Step (minutes)')
ax3.set_ylabel('Number of bridges')

sns.lineplot(data=full_df, x='Step', y='D_collapsed', hue='scenario', ax=ax4)
ax4.set_title('Collapsed bridges of condition D')
ax4.set_xlabel('Step (minutes)')
ax4.set_ylabel('Number of bridges')

plt.savefig('img/lineplot_collapsed_condition.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 4
#       1 fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 15))
#       2 fig.suptitle('Total number of collapsed bridges')
# ----> 4 sns.lineplot(data=full_df, x='Step', y='A_collapsed', hue='scenario', ax=ax1)
#       5 ax1.set_title('Collapsed bridges of condition A')
#       6 ax1.set_xlabel('Step (minutes)')
#
# File ~\anaconda3\lib\site-packages\seaborn\relational.py:645, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     642 color = kwargs.pop("color", kwargs.pop("c", None))
#     643 kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)
# --> 645 p.plot(ax, kwargs)
#     646 return ax
#
# File ~\anaconda3\lib\site-packages\seaborn\relational.py:441, in _LinePlotter.plot(self, ax, kws)
#     438     grouped = sub_data.groupby(orient, sort=self.sort)
#     439     # Could pass as_index=False instead of reset_index,
#     440     # but that fails on a corner case with older pandas.
# --> 441     sub_data = grouped.apply(agg, other).reset_index()
#     442 else:
#     443     sub_data[f"{other}min"] = np.nan
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:1567, in GroupBy.apply(self, func, *args, **kwargs)
#    1559     new_msg = (
#    1560         f"The operation {orig_func} failed on a column. If any error is "
#    1561         f"raised, this will raise an exception in a future version "
#    1562         f"of pandas. Drop these columns to avoid this warning."
#    1563     )
#    1564     with rewrite_warning(
#    1565         old_msg, FutureWarning, new_msg
#    1566     ) if is_np_func else nullcontext():
# -> 1567         result = self._python_apply_general(f, self._selected_obj)
#    1568 except TypeError:
#    1569     # gh-20949
#    1570     # try again, with .apply acting as a filtering
#    (...)
#    1574     # fails on *some* columns, e.g. a numeric operation
#    1575     # on a string grouper column
#    1577     with self._group_selection_context():
#    1578         # GH#50538
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:1629, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1592 @final
#    1593 def _python_apply_general(
#    1594     self,
#    (...)
#    1599     is_agg: bool = False,
#    1600 ) -> NDFrameT:
#    1601     """
#    1602     Apply function f in python space
#    1603
#    (...)
#    1627         data after applying f
#    1628     """
# -> 1629     values, mutated = self.grouper.apply(f, data, self.axis)
#    1630     if not_indexed_same is None:
#    1631         not_indexed_same = mutated or self.mutated
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\ops.py:839, in BaseGrouper.apply(self, f, data, axis)
#     837 # group might be modified
#     838 group_axes = group.axes
# --> 839 res = f(group)
#     840 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     841     mutated = True
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:1540, in GroupBy.apply.<locals>.f(g)
#    1537 @wraps(func)
#    1538 def f(g):
#    1539     with np.errstate(all="ignore"):
# -> 1540         return func(g, *args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\seaborn\_statistics.py:514, in EstimateAggregator.__call__(self, data, var)
#     512     units = data.get("units", None)
#     513     boots = bootstrap(vals, units=units, func=self.estimator, **self.boot_kws)
# --> 514     err_min, err_max = _percentile_interval(boots, self.error_level)
#     516 return pd.Series({var: estimate, f"{var}min": err_min, f"{var}max": err_max})
#
# File ~\anaconda3\lib\site-packages\seaborn\_statistics.py:523, in _percentile_interval(data, width)
#     521 edge = (100 - width) / 2
#     522 percentiles = edge, 100 - edge
# --> 523 return np.nanpercentile(data, percentiles)
#
# File <__array_function__ internals>:180, in nanpercentile(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1384, in nanpercentile(a, q, axis, out, overwrite_input, method, keepdims, interpolation)
#    1382 if not function_base._quantile_is_valid(q):
#    1383     raise ValueError("Percentiles must be in the range [0, 100]")
# -> 1384 return _nanquantile_unchecked(
#    1385     a, q, axis, out, overwrite_input, method, keepdims)
#
# File ~\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1559, in _nanquantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims)
#    1557 if a.size == 0:
#    1558     return np.nanmean(a, axis, out=out, keepdims=keepdims)
# -> 1559 r, k = function_base._ureduce(a,
#    1560                               func=_nanquantile_ureduce_func,
#    1561                               q=q,
#    1562                               axis=axis,
#    1563                               out=out,
#    1564                               overwrite_input=overwrite_input,
#    1565                               method=method)
#    1566 if keepdims and keepdims is not np._NoValue:
#    1567     return r.reshape(q.shape + k)
#
# File ~\anaconda3\lib\site-packages\numpy\lib\function_base.py:3725, in _ureduce(a, func, **kwargs)
#    3722 else:
#    3723     keepdim = (1,) * a.ndim
# -> 3725 r = func(a, **kwargs)
#    3726 return r, keepdim
#
# File ~\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1581, in _nanquantile_ureduce_func(a, q, axis, out, overwrite_input, method)
#    1579 if axis is None or a.ndim == 1:
#    1580     part = a.ravel()
# -> 1581     result = _nanquantile_1d(part, q, overwrite_input, method)
#    1582 else:
#    1583     result = np.apply_along_axis(_nanquantile_1d, axis, a, q,
#    1584                                  overwrite_input, method)
#
# File ~\anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1607, in _nanquantile_1d(arr1d, q, overwrite_input, method)
#    1603 if arr1d.size == 0:
#    1604     # convert to scalar
#    1605     return np.full(q.shape, np.nan, dtype=arr1d.dtype)[()]
# -> 1607 return function_base._quantile_unchecked(
#    1608     arr1d, q, overwrite_input=overwrite_input, method=method)
#
# File ~\anaconda3\lib\site-packages\numpy\lib\function_base.py:4424, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims)
#    4416 def _quantile_unchecked(a,
#    4417                         q,
#    4418                         axis=None,
#    (...)
#    4421                         method="linear",
#    4422                         keepdims=False):
#    4423     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 4424     r, k = _ureduce(a,
#    4425                     func=_quantile_ureduce_func,
#    4426                     q=q,
#    4427                     axis=axis,
#    4428                     out=out,
#    4429                     overwrite_input=overwrite_input,
#    4430                     method=method)
#    4431     if keepdims:
#    4432         return r.reshape(q.shape + k)
#
# File ~\anaconda3\lib\site-packages\numpy\lib\function_base.py:3725, in _ureduce(a, func, **kwargs)
#    3722 else:
#    3723     keepdim = (1,) * a.ndim
# -> 3725 r = func(a, **kwargs)
#    3726 return r, keepdim
#
# File ~\anaconda3\lib\site-packages\numpy\lib\function_base.py:4593, in _quantile_ureduce_func(a, q, axis, out, overwrite_input, method)
#    4591     else:
#    4592         arr = a.copy()
# -> 4593 result = _quantile(arr,
#    4594                    quantiles=q,
#    4595                    axis=axis,
#    4596                    method=method,
#    4597                    out=out)
#    4598 return result
#
# File ~\anaconda3\lib\site-packages\numpy\lib\function_base.py:4691, in _quantile(arr, quantiles, axis, method, out)
#    4687 previous_indexes, next_indexes = _get_indexes(arr,
#    4688                                               virtual_indexes,
#    4689                                               values_count)
#    4690 # --- Sorting
# -> 4691 arr.partition(
#    4692     np.unique(np.concatenate(([0, -1],
#    4693                               previous_indexes.ravel(),
#    4694                               next_indexes.ravel(),
#    4695                               ))),
#    4696     axis=DATA_AXIS)
#    4697 if np.issubdtype(arr.dtype, np.inexact):
#    4698     slices_having_nans = np.isnan(
#    4699         take(arr, indices=-1, axis=DATA_AXIS)
#    4700     )
#
# KeyboardInterrupt:
